# %% [markdown]
# # Setup

# %%
# Import necessary modules and libraries
from abc import ABC, abstractmethod
import base64
import requests
import pandas as pd

# %% [markdown]
# # Define FlexStackAPIHub

# %%
class FlexStack(ABC):
    @abstractmethod
    def generate(self):
        """
        Generate method to be implemented by subclasses. This method should handle the generation process specific to the subclass.
        """
        pass


class FlexStackAPIHub(FlexStack):
    """
    FlexStackAPIHub is a class designed to interact with the FlexStack API Marketplace.
    It allows for user authentication, listing available APIs, retrieving API usage guides,
    adding new APIs to the marketplace, and making API calls.

    Attributes:
        url (str): The base URL for the FlexStack API Marketplace.
        token (str): Authentication token for the API Marketplace.
        apis (pd.DataFrame): A DataFrame containing the list of available APIs.
    """

    def __init__(self, url: str, token: str) -> None:
        """
        Initializes the FlexStackAPIHub class with a base URL and an authentication token.

        Args:
            url (str): The base URL for the FlexStack API Marketplace.
            token (str): Authentication token for the API Marketplace.
        """
        self.url = url
        self.token = token
        self.apis = self.list_api()

    @classmethod
    def login(cls, username: str, password: str) -> 'FlexStackAPIHub':
        """
        Authenticates a user with the FlexStack API Marketplace and returns an instance of the class.

        Args:
            username (str): The username for login.
            password (str): The password for login.

        Returns:
            FlexStackAPIHub: An instance of the class with an authentication token.
        """
        def basic_auth(username: str, password: str) -> str:
            token = base64.b64encode(f"{username}:{password}".encode('utf-8')).decode("ascii")
            return f'Basic {token}'

        base_url = 'https://api.joinparrot.ai/v1' 

        url = f'{base_url}/user/login'

        headers = {'Authorization': basic_auth(username, password)}
        response = requests.post(url, headers=headers)
        if response.status_code == 200:
            print("[INFO] Login success")
        else:
            print(f"[ERROR] Login failed. {response.text}")
        token = response.json()["data"]["access_token"]
        return cls(base_url, token)

    def list_api(self) -> pd.DataFrame:
        """
        Retrieves a list of available APIs from the FlexStack API Marketplace.

        Returns:
            pd.DataFrame: A DataFrame containing the list of available APIs.
        """
        api_list_url = f'{self.url}/api-market/list-api'
        headers = {'Authorization': f'Bearer {self.token}'}
        response = requests.get(api_list_url, headers=headers)
        if response.status_code == 200:
            return pd.DataFrame(response.json()['data'])
        else:
            raise Exception(f"Error: {response.status_code}, {response.text}")

    def guide_usage(self, api_id: int) -> pd.Series:
        """
        Retrieves the usage guide for a specific API by its ID.

        Args:
            api_id (int): The ID of the API.

        Returns:
            pd.Series: A Series containing the usage information of the specified API.
        """
        self.apis = self.list_api()
        api_info = self.apis[self.apis['id'] == api_id].iloc[0]

        api_name = api_info['name']
        endpoint = api_info.api_path

        examples = {}
        if api_info.method == "POST" and "application" in api_info.body_type:
            examples = {"body": {}}
            for param in api_info.params:
                examples['body'].update({param['key']: ""})
        if api_info.method == "GET":
            examples = {"query": {}}
            for param in api_info.params:
                examples['query'].update({param['key']: ""})
                
        print("> Usage Guide")
        print(f"\t- API Name: {api_name}")
        print(f"\t- Endpoint: {endpoint}")
        print("\t- Parameters:")
        for param in api_info.params:
            print(f"\t\t- {param['key']}: {param['desc']}")
        print(f"\t- Examples: \n\t{examples}")

        return api_info

    def add_api(self, type: str, data: dict) -> dict:
        """
        Adds a new API to the FlexStack API Marketplace.

        Args:
            type (str): The type of API being added (e.g., "FORM", "POSTMAN_COLLECTION", "OPENAPI").
            data (dict): The data required to add the new API.

        Returns:
            dict: The response from the API Marketplace after adding the new API.
        """
        if type not in ["FORM", "POSTMAN_COLLECTION", "OPENAPI"]:
            raise ValueError(f"Error: Unsupported API type '{type}'.")
        add_api_url = f'{self.url}/api-market/add'
        headers = {'Authorization': f'Bearer {self.token}'}
        response = requests.post(add_api_url, json=data, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            raise Exception(f"Error: {response.status_code}, {response.text}")

    def generate(self, endpoint: str, data: dict) -> dict:
        """
        Makes a call to a specified API endpoint with provided data.

        Args:
            endpoint (str): The endpoint of the API to be called.
            data (dict): The data to be sent in the API call.

        Returns:
            dict: The response from the API call.
        """
        headers = {'Authorization': f'Bearer {self.token}'}
        response = requests.post(endpoint, json=data, headers=headers)
        return response.json()

# %% [markdown]
# # API Market

# %% [markdown]
# ## Login

# %%
username = "<your-username>"
password = "<your-password>"

# Login
flexstack_apihub = FlexStackAPIHub.login(username, password)
# Out:
# [INFO] Login success

# %% [markdown]
# ## Discovery

# %%
flexstack_apihub.list_api() # View list API
# Out:
#      id                                           api_path  \
# 0   110  https://api.joinparrot.ai/v1/api-market/use/88...
# 1   108  https://api.joinparrot.ai/v1/api-market/use/ed...
# 2   106  https://api.joinparrot.ai/v1/api-market/use/76...
# 3   105  https://api.joinparrot.ai/v1/api-market/use/85...
# 4   102  https://api.joinparrot.ai/v1/api-market/use/63...
# 5   101  https://api.joinparrot.ai/v1/api-market/use/91...
# 6   100  https://api.joinparrot.ai/v1/api-market/use/bb...
# 7    98  https://api.joinparrot.ai/v1/api-market/use/d1...
# 8    97  https://api.joinparrot.ai/v1/api-market/use/25...
# 9    96  https://api.joinparrot.ai/v1/api-market/use/f2...
# 10   92  https://api.joinparrot.ai/v1/api-market/use/15...
# 11   90  https://api.joinparrot.ai/v1/api-market/use/72...
# 12   88  https://api.joinparrot.ai/v1/api-market/use/6f...
# 13   87  https://api.joinparrot.ai/v1/api-market/use/c3...
# 14   86  https://api.joinparrot.ai/v1/api-market/use/ee...
# 15   85  https://api.joinparrot.ai/v1/api-market/use/e2...
# 16   84  https://api.joinparrot.ai/v1/api-market/use/75...
# 17   83  https://api.joinparrot.ai/v1/api-market/use/7f...
# 18   82  https://api.joinparrot.ai/v1/api-market/use/ac...
# 19   81  https://api.joinparrot.ai/v1/api-market/use/0d...
# 20   78  https://api.joinparrot.ai/v1/api-market/use/9b...
# 21   77  https://api.joinparrot.ai/v1/api-market/use/be...
# 22   74  https://api.joinparrot.ai/v1/api-market/use/22...
# 23   73  https://api.joinparrot.ai/v1/api-market/use/94...
# 24   72  https://api.joinparrot.ai/v1/api-market/use/16...
# 25   71  https://api.joinparrot.ai/v1/api-market/use/22...
# 26   70  https://api.joinparrot.ai/v1/api-market/use/a8...
# 27   69  https://api.joinparrot.ai/v1/api-market/use/86...
# 28   68  https://api.joinparrot.ai/v1/api-market/use/1e...
# 29   65  https://api.joinparrot.ai/v1/api-market/use/0e...
# 30   59  https://api.joinparrot.ai/v1/api-market/use/67...
# 31   57  https://api.joinparrot.ai/v1/api-market/use/e8...
# 32   56  https://api.joinparrot.ai/v1/api-market/use/98...
# 33   55  https://api.joinparrot.ai/v1/api-market/use/81...
# 34   54  https://api.joinparrot.ai/v1/api-market/use/30...
# 35   51  https://api.joinparrot.ai/v1/api-market/use/8e...
# 36   47  https://api.joinparrot.ai/v1/api-market/use/cb...
# 37   45  https://api.joinparrot.ai/v1/api-market/use/d4...
# 38   44  https://api.joinparrot.ai/v1/api-market/use/4a...
# 39   26  https://api.joinparrot.ai/v1/api-market/use/dc...
#
#                                 name                             desc method  \
# 0                  Get Fitness feeds                    Fitness feeds    GET
# 1                   Get Coffee feeds                     Coffee feeds    GET
# 2                   Get Health feeds                     Health feeds    GET
# 3                     Get Food feeds                       Food feeds    GET
# 4                     Get News feeds                       News feeds    GET
# 5                  Get Writing feeds                    Writing feeds    GET
# 6              Get Real Estate feeds                Real Estate feeds    GET
# 7              Get Photography feeds                Photography feeds    GET
# 8                      Get Law feeds                        Law feeds    GET
# 9                Get Marketing feeds                  Marketing feeds    GET
# 10                   Get Sport feeds                      Sport feeds    GET
# 11                    Get Tech feeds                       Tech feeds    GET
# 12                 Get Camping feeds                    Camping feeds    GET
# 13                 Get Fishing feeds                    Fishing feeds    GET
# 14               Get Education feeds                  Education feeds    GET
# 15              Get E-Commerce feeds                 E-Commerce feeds    GET
# 16                Get Football feeds                   Football feeds    GET
# 17                 Get Finance feeds                    Finance feeds    GET
# 18                    Get Game feeds                       Game feeds    GET
# 19                 Get Fashion feeds                    Fashion feeds    GET
# 20               Get Lifestyle feeds                  Lifestyle feeds    GET
# 21                  Get Travel feeds                     Travel feeds    GET
# 22                     Get Art feeds                        Art feeds    GET
# 23                 Get Bitcoin feeds                    Bitcoin feeds    GET
# 24              Get Board Game feeds                 Board Game feeds    GET
# 25         Get Human Resources feeds            Human Resources feeds    GET
# 26                    Get Girl feeds                       Girl feeds    GET
# 27                  Get Garden feeds                     Garden feeds    GET
# 28                     Get Pet feeds                        Pet feeds    GET
# 29                 Get History feeds                    History feeds    GET
# 30                   Get Music feeds                      Music feeds    GET
# 31  Create LLMs Text Generation Task             LLMs Text Generation   POST
# 32    Get result of audio by task id   Get result of audio by task id    GET
# 33      Create Audio Generation Task                 Audio Generation   POST
# 34      Create Image Generation Task                 Image Generation   POST
# 35    Get result of image by task id   Get result of image by task id    GET
# 36                    Translate text                   Translate text   POST
# 37   Get result translate by task id  Get result translate by task id    GET
# 38  DocTranslate.io (Translate text)                   Translate text   POST
# 39                     Get provinces         Get provinces in VietNam    GET
#
#     fee  is_active notes                                             params  \
# 0   0.0       True  None                                                 []
# 1   0.0       True  None                                                 []
# 2   0.0       True  None                                                 []
# 3   0.0       True  None                                                 []
# 4   0.0       True  None                                                 []
# 5   0.0       True  None                                                 []
# 6   0.0       True  None                                                 []
# 7   0.0       True  None                                                 []
# 8   0.0       True  None                                                 []
# 9   0.0       True  None                                                 []
# 10  0.0       True  None                                                 []
# 11  0.0       True  None                                                 []
# 12  0.0       True  None                                                 []
# 13  0.0       True  None                                                 []
# 14  0.0       True  None                                                 []
# 15  0.0       True  None                                                 []
# 16  0.0       True  None                                                 []
# 17  0.0       True  None                                                 []
# 18  0.0       True  None                                                 []
# 19  0.0       True  None                                                 []
# 20  0.0       True  None                                                 []
# 21  0.0       True  None                                                 []
# 22  0.0       True  None                                                 []
# 23  0.0       True  None                                                 []
# 24  0.0       True  None                                                 []
# 25  0.0       True  None                                                 []
# 26  0.0       True  None                                                 []
# 27  0.0       True  None                                                 []
# 28  0.0       True  None                                                 []
# 29  0.0       True  None                                                 []
# 30  0.0       True  None                                                 []
# 31  0.0       True  None  [{'key': 'messages', 'desc': 'Prompt to genera...
# 32  0.0       True  None  [{'key': 'task_id', 'desc': 'The ID of the tas...
# 33  0.0       True  None  [{'key': 'prompt', 'desc': 'Prompt to generate...
# 34  0.0       True  None  [{'key': 'prompt', 'desc': 'Prompt to generate...
# 35  0.0       True  None  [{'key': 'task_id', 'desc': 'The ID of the tas...
# 36  0.0       True        [{'key': 'text', 'desc': 'Text to be translate...
# 37  0.0       True  None  [{'key': 'task_id', 'desc': 'The ID of the tas...
# 38  0.0       True  None  [{'key': 'text', 'desc': 'Text to be translate...
# 39  0.0       True  None                                                 []
#
#                             body_type
# 0                 application/rss+xml
# 1                 application/rss+xml
# 2                 application/rss+xml
# 3                 application/rss+xml
# 4                 application/rss+xml
# 5                 application/rss+xml
# 6                 application/rss+xml
# 7                 application/rss+xml
# 8                 application/rss+xml
# 9                 application/rss+xml
# 10                application/rss+xml
# 11                application/rss+xml
# 12                application/rss+xml
# 13                application/rss+xml
# 14                application/rss+xml
# 15                application/rss+xml
# 16                application/rss+xml
# 17                application/rss+xml
# 18                application/rss+xml
# 19                application/rss+xml
# 20                application/rss+xml
# 21                application/rss+xml
# 22                application/rss+xml
# 23                application/rss+xml
# 24                application/rss+xml
# 25                application/rss+xml
# 26                application/rss+xml
# 27                application/rss+xml
# 28                application/rss+xml
# 29                application/rss+xml
# 30                application/rss+xml
# 31                   application/json
# 32                               None
# 33                   application/json
# 34                   application/json
# 35                               None
# 36  application/x-www-form-urlencoded
# 37                               None
# 38  application/x-www-form-urlencoded
# 39                               None

# %% [markdown]
# # Get API Feeds with FlexStack

# %% [markdown]
# ## Get API Info and Guide

# %% [markdown]
# ### 1. API GET Music Feeds

# %%
api_music = flexstack_apihub.guide_usage(api_id=59)
# Out:
# > Usage Guide
# 	- API Name: Get Music feeds
# 	- Endpoint: https://api.joinparrot.ai/v1/api-market/use/67f69b98b5be438289e7148e696e4a19
# 	- Parameters:
# 	- Examples:
# 	{'query': {}}

# %% [markdown]
# ### 2. API GET Tech Feeds

# %%
api_music = flexstack_apihub.guide_usage(api_id=90)
# Out:
# > Usage Guide
# 	- API Name: Get Tech feeds
# 	- Endpoint: https://api.joinparrot.ai/v1/api-market/use/72c482f543794bfc923a10fa975b20da
# 	- Parameters:
# 	- Examples:
# 	{'query': {}}

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Get result

# %%
data={} 

endpoint = "https://api.joinparrot.ai/v1/api-market/use/67f69b98b5be438289e7148e696e4a19" # Endpoint  of the API you want to use

resp = flexstack_apihub.generate(endpoint, data)                                          # Call the API to generate a response

print(resp)
# Out:
# {'data': '<?xml version="1.0" encoding="UTF-8"?><rss version="2.0"\n\txmlns:content="http://purl.org/rss/1.0/modules/content/"\n\txmlns:wfw="http://wellformedweb.org/CommentAPI/"\n\txmlns:dc="http://purl.org/dc/elements/1.1/"\n\txmlns:atom="http://www.w3.org/2005/Atom"\n\txmlns:sy="http://purl.org/rss/1.0/modules/syndication/"\n\txmlns:slash="http://purl.org/rss/1.0/modules/slash/"\n\t\n\txmlns:georss="http://www.georss.org/georss"\n\txmlns:geo="http://www.w3.org/2003/01/geo/wgs84_pos#"\n\t>\n\n<channel>\n\t<title>Billboard</title>\n\t<atom:link href="https://www.billboard.com/feed/" rel="self" type="application/rss+xml" />\n\t<link>https://www.billboard.com</link>\n\t<description>Music Charts, News, Photos &#38; Video</description>\n\t<lastBuildDate>Fri, 29 Mar 2024 13:30:35 +0000</lastBuildDate>\n\t<language>en-US</language>\n\t<sy:updatePeriod>\n\thourly\t</sy:updatePeriod>\n\t<sy:updateFrequency>\n\t1\t</sy:updateFrequency>\n\t<generator>https://wordpress.org/?v=6.4.3</generator>\n\t<item>\n\t\t<title>BMI Members to Receive $100M Bonus From New Mountain Sale. How Will It Be&#160;Split?</title>\n\t\t<link>https://www.billboard.com/pro/bmi-member-bonus-new-mountain-sale-how-split/</link>\n\t\t\n\t\t<dc:creator><![CDATA[Marc Schneider]]></dc:creator>\n\t\t<pubDate>Fri, 29 Mar 2024 13:18:51 +0000</pubDate>\n\t\t\t\t<category><![CDATA[Business]]></category>\n\t\t<category><![CDATA[Business News]]></category>\n\t\t<category><![CDATA[bmi]]></category>\n\t\t<category><![CDATA[New Mountain Capital]]></category>\n\t\t<guid isPermaLink="false">https://www.billboard.com/?post_type=billboard_pro_post&#038;p=1235644565</guid>\n\n\t\t\t\t\t<description><![CDATA[The payout leaves recipients happy but confused as they try to figure out how the bonuses were determined.]]></description>\n\t\t\t\t\t\t\t\t\t\t<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->\n\t\t\t\t<div class="pmc-paywall">\n\n\n\n\n\n\n\n\n\n\n\n\n<p\n\t\tclass="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "\n>\n\tBMI, which was <a  href="https://www.billboard.com/business/business-news/bmi-sale-new-mountain-capital-complete-pro-sold-finalized-1235602941/"  data-type="link"  data-id="https://www.billboard.com/business/business-news/bmi-sale-new-mountain-capital-complete-pro-sold-finalized-1235602941/"  >acquired</a> by New Mountain Capital in February, last night notified songwriters and publishers that its\xa0previous owners, mainly radio and TV stations, have followed through on their commitment to disburse a $100 million bonus from the undisclosed amount received for the sale — which sources say was over $1 billion — to songwriters and publishers. What’s more, it\xa0disclosed to each songwriter and publisher how much they will be receiving.</p>\n\n\n\n<p\n\t\tclass="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "\n>\n\tSongwriters and publishers expressed gratitude&nbsp;for the payout — after all, the sellers were under no legal obligation to share any of the sale price with BMI members. In fact, some consider it a very generous reward from the prior owners. However, other&nbsp;sources have&nbsp;suggested that morally, the previous owners should shared&nbsp;something, considering it was songwriters&#8217;&nbsp;and music publishers&#8217; rights that generated all the licensing revenue and created the value for the sale price to be achieved.</p>\n\n\n<div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >\n\t\t\t<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">\n\t\t\t\n<h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">\n\n\t\n\t\n\t\t\n\t\t\t\t\tRelat ...

# %% [markdown]
# ### Get data feeds

# %%
data_content = resp['data'] # Get data from response
print(data_content)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rss version="2.0"
# 	xmlns:content="http://purl.org/rss/1.0/modules/content/"
# 	xmlns:wfw="http://wellformedweb.org/CommentAPI/"
# 	xmlns:dc="http://purl.org/dc/elements/1.1/"
# 	xmlns:atom="http://www.w3.org/2005/Atom"
# 	xmlns:sy="http://purl.org/rss/1.0/modules/syndication/"
# 	xmlns:slash="http://purl.org/rss/1.0/modules/slash/"
#
# 	xmlns:georss="http://www.georss.org/georss"
# 	xmlns:geo="http://www.w3.org/2003/01/geo/wgs84_pos#"
# 	>
#
# <channel>
# 	<title>Billboard</title>
# 	<atom:link href="https://www.billboard.com/feed/" rel="self" type="application/rss+xml" />
# 	<link>https://www.billboard.com</link>
# 	<description>Music Charts, News, Photos &#38; Video</description>
# 	<lastBuildDate>Fri, 29 Mar 2024 13:30:35 +0000</lastBuildDate>
# 	<language>en-US</language>
# 	<sy:updatePeriod>
# 	hourly	</sy:updatePeriod>
# 	<sy:updateFrequency>
# 	1	</sy:updateFrequency>
# 	<generator>https://wordpress.org/?v=6.4.3</generator>
# 	<item>
# 		<title>BMI Members to Receive $100M Bonus From New Mountain Sale. How Will It Be&#160;Split?</title>
# 		<link>https://www.billboard.com/pro/bmi-member-bonus-new-mountain-sale-how-split/</link>
#
# 		<dc:creator><![CDATA[Marc Schneider]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 13:18:51 +0000</pubDate>
# 				<category><![CDATA[Business]]></category>
# 		<category><![CDATA[Business News]]></category>
# 		<category><![CDATA[bmi]]></category>
# 		<category><![CDATA[New Mountain Capital]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?post_type=billboard_pro_post&#038;p=1235644565</guid>
#
# 					<description><![CDATA[The payout leaves recipients happy but confused as they try to figure out how the bonuses were determined.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	BMI, which was <a  href="https://www.billboard.com/business/business-news/bmi-sale-new-mountain-capital-complete-pro-sold-finalized-1235602941/"  data-type="link"  data-id="https://www.billboard.com/business/business-news/bmi-sale-new-mountain-capital-complete-pro-sold-finalized-1235602941/"  >acquired</a> by New Mountain Capital in February, last night notified songwriters and publishers that its previous owners, mainly radio and TV stations, have followed through on their commitment to disburse a $100 million bonus from the undisclosed amount received for the sale — which sources say was over $1 billion — to songwriters and publishers. What’s more, it disclosed to each songwriter and publisher how much they will be receiving.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Songwriters and publishers expressed gratitude&nbsp;for the payout — after all, the sellers were under no legal obligation to share any of the sale price with BMI members. In fact, some consider it a very generous reward from the prior owners. However, other&nbsp;sources have&nbsp;suggested that morally, the previous owners should shared&nbsp;something, considering it was songwriters&#8217;&nbsp;and music publishers&#8217; rights that generated all the licensing revenue and created the value for the sale price to be achieved.</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/pro/bmis-sale-benefit-songwriters-taylor-swift/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/2023/10/taylor-swift-eras-tour-19-pro-2023-billboard-pro-1260.jpg?w=237&#038;h=147&#038;crop=1" alt="Taylor Swift" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					Which Songwriters Will Benefit From the BMI&nbsp;Sale?
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	In any event, publishers and songwriters contacted by <em>Billboard</em> Thursday (March 28)&nbsp;said they were engaging in mathematical analysis to try and figure out what their payment represented, even though BMI laid out on its website some details on how it arrived at each individual payout. According to the website, BMI looked at the most recent five years of payouts&nbsp;(2019-2023)&nbsp;and used that as a basis to determine how much each payout should be —&nbsp;after taking into consideration whether the songwriter’s catalog was there for all five years or is still there even if the songwriter has left. Then, it apparently divided songwriters into tiers based on&nbsp;undisclosed parameters and paid every songwriter or publisher in that tier the same amount according to the website. Only songwriters or publishers that had received over $500 in royalties were eligible for a bonus distribution.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	BMI&nbsp;didn’t provide any information on how it calculated allocations other than to say it split the bonus payouts evenly between songwriters and publishers —&nbsp;and that sold catalogs&#8217;&nbsp;bonuses&nbsp;would be pro-rated between the new owners and old owners. But it&nbsp;did disclose that the method it used “is different from how we calculate our quarterly distributions,&#8221; according to the letter signed by BMI president/CEO <strong>Mike O’Neill </strong>that accompanied news of the allocation. “We thought very carefully about how we determined this allocation and made every effort to be as inclusive as possible and have it applied to the greatest number of earning BMI affiliates,” O’Neill’s letter stated. “Your allocation is truly well deserved, and I&#8217;m very pleased to deliver it to you on behalf of BMI&#8217;s former shareholders. Moving forward, your future with BMI is brighter than ever.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Meanwhile, publishers&#8217; data teams spent the day analyzing the payouts, looking at instances where they could see payouts on multiple catalogs or songwriters with similar characteristics for the five-year terms in order to compare them. Others measured their bonus payout as a percentage of the $100 million or compared it to the suspected sale price.</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/business/business-news/bmi-sale-new-mountain-capital-complete-pro-sold-finalized-1235602941/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/2022/10/mike-oneill-bmi-1260.jpg?w=237&#038;h=147&#038;crop=1" alt="Mike O&#039;Neill" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					BMI Sale to New Mountain Capital Is Now&nbsp;Complete
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Still others decided that the best way to measure the bonus was to add up all the royalties BMI paid for a song catalog for the five-year period to see what percentage of that amount&nbsp;the bonus comprised; and then to compare that percentage with other songwriters or catalogs. One such catalog, an A-level writer/producer with several No. 1 hits during the period, earned about $4.1 million from BMI over those five years&nbsp;and received a bonus of $47,000 —&nbsp;or a 1.15% bonus on the earnings for the period, according to one source who had access to that data.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Another publishing source says comparing songwriters on its rosters&nbsp;who are equally successful to what each received as a bonus created quite a bit of confusion. In one instance,&nbsp;when they&nbsp;compared&nbsp;two songwriters at the same level, both got the same amount&nbsp;even though&nbsp;one has been at BMI for all five years&nbsp;while the other has only been there for only&nbsp;a few of the five years. “BMI might file this under ‘no good deed goes unpunished’ or ‘looking a gift horse in the mouth,’ but so far I can’t see any rhyme or reason on how they are determining the payouts,” that publisher says, but quickly adds, “Having said that, I am very happy for getting the money.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	A&nbsp;BMI representative was unavailable to comment at deadline — the organization was holding its Trailblazers of Gospel Music Awards event in Atlanta on Thursday. But the O’Neill letter to those receiving bonus payments also noted that the new owners will give BMI increased capabilities and leave the organization in &#8220;the best possible position to tap into numerous growth opportunities that will ensure your long-term success…increasing your distributions, elevating the services we provide and exploring new revenue streams that will benefit you.&#8221;</p>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Utopia Music Looking for &#8216;Fresh Start&#8217; With Proper&#160;Rebrand</title>
# 		<link>https://www.billboard.com/business/business-news/utopia-music-name-change-proper-music-group-rebrand-1235644556/</link>
#
# 		<dc:creator><![CDATA[Marc Schneider]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 11:51:48 +0000</pubDate>
# 				<category><![CDATA[Business]]></category>
# 		<category><![CDATA[Business News]]></category>
# 		<category><![CDATA[International]]></category>
# 		<category><![CDATA[Utopia Music]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644556</guid>
#
# 					<description><![CDATA[A switch to Proper Music Group follows a tumultuous '23, and reflects "changes to our strategic direction, where distribution sits at the core of the commercial value chain."]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	LONDON — Utopia Music is planning to rebrand as Proper Group AG, named after its core physical music distribution business, to reflect changes to the Swiss-based firm’s “strategic direction,” the company said Thursday (March 28).</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The proposed name change, which needs to be approved by shareholders, comes almost two months after co-founder and former head <strong>Mattias Hjelmstedt</strong> exited Utopia Music following a shake-up of its executive ranks.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	“As Utopia has evolved under new leadership, we recognize the need to align our brand with our new strategy and as a result, new market positioning,” said <strong>Michael Stebler</strong>, who was appointed CEO in January, in a statement sent to <em>Billboard</em>.</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/business/business-news/utopia-music-co-founder-mattias-hjelmstedt-exits-1235596130/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/2023/02/Mattias-Hjelmstedt-cr-Courtesy-of-Utopia-Music-press-2023-billboard-1548.jpg?w=237&#038;h=147&#038;crop=1" alt="Mattias Hjelmstedt" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					Utopia Music Co-Founder Mattias Hjelmstedt Exits&nbsp;Company
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	“Our previous brand identity doesn’t accurately reflect who we are today and where we aim to go in the future,” said the chief executive – a former managing director of Investment Advisors Zug AG, which operated on behalf of Utopia’s majority shareholder group. Like Utopia Music, Investment Advisors Zug AG is headquartered in the scenic Swiss town of Zug, located close to Zurich.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Utopia Music acquired Proper Music Group, the United Kingdom&#8217;s biggest independent physical music distributor, which provides distribution services for nearly 6,000 indie labels and service companies, for an undisclosed sum in January 2022.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Eight months later, the company bought up the assets of U.K.-based Cinram Novum — which provides warehouse, fulfillment and distribution services to music labels and home entertainment companies, including Universal Music Group, Sony Music Entertainment and [PIAS] — and renamed it Utopia Distribution Services (UDS).&nbsp;&nbsp;</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Both acquisitions took place during a period of intense hyper-growth between 2020 and 2022 when Utopia rapidly acquired 15 companies spanning music tech, finance, publishing, marketing and distribution.</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/pro/utopia-music-new-ceo-alain-couttolenc-interview/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/2023/10/alain-couttolenc-press-2023-billboard-pro-1260.jpg?w=237&#038;h=147&#038;crop=1" alt="Alain Couttolenc, Utopia Music" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					Utopia Hits Refresh With New CEO After Year of Setbacks: &#8216;That&#8217;s a Closed&nbsp;Chapter&hellip;
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	A well-documented downsizing followed, encompassing multiple rounds of job cuts, company divestments and ongoing legal actions, eventually leading to the appointment of a new CEO and executive team at the start of the year.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Changing the company’s name to Proper Group “represents a fresh start,” said Stebler, “and reflects the changes to our strategic direction, where distribution sits at the core of the commercial value chain.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Under the new arrangement, <em>Billboard</em> understands that Utopia/Proper Group will be divided into four main departments: Proper Distribution, Proper Payments, Proper Processing and Proper Music Data.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Together, the company says, they will provide clients with a “comprehensive suite of tech services” &#8212; including cross-platform analytics and royalty tracking, processing and payments &#8212; all built around the firm’s music distribution business, which has long generated the bulk of its revenue.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	“By leveraging the Proper brand,” the company will “benefit from the positive and strong brand equity Proper has in the music industry,” said Stebler.&nbsp;</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/pro/digital-markets-act-impact-music-business-europe-explained/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/media/European-Union-flag-billboard-a-1548.jpg?w=237&#038;h=147&#038;crop=1" alt="European Union" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					What Europe&#8217;s Digital Markets Act Means for the Music&nbsp;Business
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The company’s executive team remains unchanged with Stebler supported by deputy CEOs <strong>Alain Couttolenc a</strong>nd <strong>Drew Hill</strong>, a long-serving veteran of the U.K. physical music industry, who doubles as Utopia/Proper Group’s chief of distribution.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Hill’s responsibilities include overseeing the U.K.’s biggest distribution warehouse for physical music and home entertainment — a 25,000-square meter facility in the town of Bicester with handling capacity of up to 250,000 units per day — which Utopia opened last year as part of a £100 million ($125 million) long-term deal with international logistics company DP World.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	More recently, Utopia successfully secured around half of a Series C funding round (understood to total more than 15 million euros) &nbsp;with a second tranche of C-round funding underway. The funds will be used to drive commercial growth, enhance product development and strengthen the company’s balance sheet, Stebler told <em>Billboard</em> in January.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Shareholders will get to vote on the proposed name change when Utopia holds its Annual General Meeting at the start of May.</p>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Beyoncé&#8217;s &#8216;Cowboy Carter&#8217;: All 27 Tracks&#160;Ranked</title>
# 		<link>https://www.billboard.com/lists/beyonce-cowboy-carter-all-27-tracks-ranked-texas-hold-em/</link>
#
# 		<dc:creator><![CDATA[Kyle-Brandon Denis]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 11:00:23 +0000</pubDate>
# 				<category><![CDATA[Country]]></category>
# 		<category><![CDATA[Music]]></category>
# 		<category><![CDATA[Cowboy Carter]]></category>
# 		<category><![CDATA[music]]></category>
# 		<category><![CDATA[Music News]]></category>
# 		<category><![CDATA[Texas Hold 'Em]]></category>
# 		<category><![CDATA[Tracks Ranked]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?post_type=pmc_list&#038;p=1235643498</guid>
#
# 					<description><![CDATA[Park your Lexus, throw your keys up and dig into <em>Billboard's</em> preliminary ranking and review of Beyoncé's eighth solo studio album.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-not-a-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	If you haven&#8217;t already, it&#8217;s officially time to trade in your silver and chrome outfits for chaps, lassos and rustic cowboy hats. On Friday (March 29), <a  href="https://www.billboard.com/artist/beyonce"  >Beyoncé</a> finally shared her highly anticipated <em>Cowboy Carter</em> album with the world.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Born out of &#8220;an experience that [she] had years ago where [she] did not feel welcomed,&#8221; Beyoncé&#8217;s latest record is a jaw-dropping ode to the breadth of regional and musical subcultures of the American South. From a fierce reimagining of <a  href="https://www.billboard.com/artist/dolly-parton/"  >Dolly Parton</a>&#8216;s classic &#8220;Jolene&#8221; to mind-blowing hybrids of country and house (&#8220;Riiverdance&#8221;), somehow, <em>Cowboy Carter</em> finds Beyoncé more experimental and more fearless than ever before.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Although the road to <em>Cowboy Carter</em> began with Queen Bey&#8217;s upbringing in Houston, TX and reached an inflection point during the <a  href="https://www.billboard.com/music/music-news/beyonce-cmas-cowboy-carter-1235636304/"  >2016 CMA Awards</a>, the Grammy winner formally kicked off the album campaign during the <a  href="https://www.billboard.com/music/pop/beyonce-announces-new-music-verizon-super-bowl-commercial-1235605215/"  >2024 Super Bowl</a> with the <a  href="https://www.billboard.com/music/rb-hip-hop/beyonce-releases-new-songs-texas-hold-em-16-carriages-super-bowl-2024-1235605227/"  >dual release</a> of &#8220;16 Carriages&#8221; and &#8220;Texas Hold &#8216;Em.&#8221; The former provided a gorgeous preview of the LP&#8217;s slower, more introspective moments, while the latter etched its name in the <em>Billboard</em> history books almost immediately. With &#8220;Texas Hold &#8216;Em,&#8221; Beyoncé became both the <a  href="https://www.billboard.com/music/chart-beat/beyonce-texas-hold-em-number-1-hot-country-songs-chart-1235610582/"  >first Black woman to top Hot Country Songs</a> and the first Black woman to send a country song to the top of the <a  href="https://www.billboard.com/charts/billboard-200/"  >Billboard Hot 100</a>. Moreover, other Black women in country &#8212; including <a  href="https://www.billboard.com/artist/reyna-roberts/"  >Reyna Roberts</a>, Linda Martell and Tanner Adell &#8212; experienced streaming boosts thanks to &#8220;Texas.&#8221;</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Both Martell and Adell appear on <em>Cowboy Carter</em>, alongside a star-studded list of collaborators that includes <a  href="https://www.billboard.com/artist/miley-cyrus/"  >Miley Cyrus</a>. Parton, <a  href="https://www.billboard.com/artist/willie-nelson/"  >Willie Nelson</a>, <a  href="https://www.billboard.com/artist/post-malone/"  >Post Malone</a>, <a  href="https://www.billboard.com/artist/shaboozey/"  >Shaboozey</a>, <a  href="https://www.billboard.com/artist/willie-jones/"  >Willie Jones</a>, <a  href="https://www.billboard.com/artist/the-dream/"  >The-Dream</a>, <a  href="https://www.billboard.com/artist/raphael-saadiq/"  >Raphael Saadiq</a>, <a  href="https://www.billboard.com/artist/pharrell-williams/"  >Pharrell Williams</a> and more. Presented as both the official follow-up to and &#8220;a continuation of&#8221; her Grammy-winning <a  href="https://www.billboard.com/charts/billboard-200/"  >Billboard 200</a>-topping <em><a  href="https://www.billboard.com/culture/pride/hrc-beyonce-renaissance-syllabus-hbcu-1235640435/"  >Renaissance</a> </em>album, <em>Cowboy Carter</em> is just the latest in a decade-long string of projects that prove that Beyoncé is one of the all-time greats.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	From the rousing &#8220;II Hands II Heaven&#8221; to the shape-shifting &#8220;Sweet ★ Honey ★ Buckiin,&#8221; here are all 27 tracks on <em>Cowboy Carter</em> ranked.</p>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="pmc-gallery-vertical">
# 	<div class="c-gallery-vertical-loader u-gallery-app-shell-loader">
#
# 		<div class="u-gallery-app-shell__figure u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__text u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__text-small u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__content u-gallery-app-shell__content-1 u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__content u-gallery-app-shell__content-2 u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__content u-gallery-app-shell__content-3 u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div><div class="u-gallery-app-shell__content u-gallery-app-shell__content-4 u-gallery-app-shell u-gallery-react-placeholder-shimmer"></div>
#
# 	</div>
# </div>
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Blusher Are Hard to Catch With ‘Accelerator’: Stream It&#160;Now</title>
# 		<link>https://www.billboard.com/music/pop/blusher-accelerator-stream-it-now-1235644470/</link>
#
# 		<dc:creator><![CDATA[Lars Brandle]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 07:50:31 +0000</pubDate>
# 				<category><![CDATA[Music]]></category>
# 		<category><![CDATA[Pop]]></category>
# 		<category><![CDATA[bbnews]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644470</guid>
#
# 					<description><![CDATA["'Accelerator' feels like a late night highway chase," Blusher says of the new single.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<a  href="https://www.billboard.com/pro/australia-blusher-signs-atlantic-exclusive/"  >Blusher</a> puts the pedal to the metal with “Accelerator,” the Australian pop-trio’s latest single. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Produced by Donny Bravo (Disclosure), the club-ready electro-pop track is the product of an inspired and highly-caffeinated morning, the singers still buzzing from a late, late night watching a Tove Lo and Associanu DJ set.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Bravo captures the “chaotic vibes” and energy that spilled out during the sessions, recounts the Melbourne trio. “&#8217;Accelerator&#8217; feels like a late night highway chase &#8211; when you embrace the chaos of not knowing where you’re going and jump head first into a feeling,” the Aussie artists tell <em>Billboard</em> via email. “We have never been more excited about a song.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Blusher (Miranda Ward, Lauren Coutts and Jade Ingvarson-Favretto) formed in 2021, and got tongues wagging the following year with the independently-released “Softly Spoken,” which enjoyed support from national youth network triple j and its Unearthed sister station (triple j premiered &#8220;Accelerator&#8221; this week).</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	They produce and write together, share vocals on many of their songs and swap instruments during their choreographed live performances, which have included showcases at the Bigsound conference in Brisbane and the inaugural SXSW Sydney. In 2023, Atlantic Records signed the pop group <a  href="https://www.billboard.com/pro/australia-blusher-signs-atlantic-exclusive/"  >to its roster</a>. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Currently, Blusher is on the road with Dadi Freyr playing their first U.S. shows. “It’s been the perfect opportunity to test out &#8216;Accelerator&#8217; on a live audience, and we have been blown away by the crowds’ reaction,” Blusher tells <em>Billboard</em>. &#8220;When we pull out sci-fi sunglasses and synchronized dance moves they are always down to match our chaotic energy on stage.&#8221;</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	They&#8217;re getting around in a small band van, which has the cute nickname Vangelina Jolie. “Now we have met so many lovely new fans at the shows who really feel like they will be fans for life. It means the world to us that America has embraced us with open arms on our first tour here,” Blusher gush. “It’s just the beginning and we can’t wait to play a lot more U.S. shows in the future.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Blusher was nominated for best new artist at the <a  href="https://www.billboard.com/music/awards/tones-and-i-crowded-house-winners-2024-rolling-stone-australia-awards-1235641237/"  >2024 Rolling Stone Australia Awards</a>, presented this week at Sydney’s The Ivy. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Stream “Accelerator” below.</p>
#
#
#
# <figure class="wp-block-embed is-type-video is-provider-youtube wp-block-embed-youtube"><div class="wp-block-embed__wrapper">
# <iframe loading="lazy" class="youtube-player" width="640" height="360" src="https://www.youtube.com/embed/rP01qO1vbws?version=3&#038;rel=1&#038;showsearch=0&#038;showinfo=1&#038;iv_load_policy=1&#038;fs=1&#038;hl=en-US&#038;autohide=2&#038;wmode=transparent" allowfullscreen="true" style="border:0;" sandbox="allow-scripts allow-same-origin allow-popups allow-presentation allow-popups-to-escape-sandbox"></iframe>
# </div></figure>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<br></p>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Ariana Grande Extends Chart Reign In Australia With ‘Eternal&#160;Sunshine’</title>
# 		<link>https://www.billboard.com/music/chart-beat/ariana-grande-extends-chart-reign-australia-eternal-sunshine-1235644453/</link>
#
# 		<dc:creator><![CDATA[Lars Brandle]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 07:05:59 +0000</pubDate>
# 				<category><![CDATA[Chart Beat]]></category>
# 		<category><![CDATA[Music]]></category>
# 		<category><![CDATA[Aria]]></category>
# 		<category><![CDATA[australia]]></category>
# 		<category><![CDATA[bbnews]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644453</guid>
#
# 					<description><![CDATA["Eternal Sunshine" enters a third week atop the ARIA Albums Chart.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<a  href="https://www.billboard.com/artist/ariana-grande/"  >Ariana Grande</a> holds at No. 1 in Australia with <em>Eternal Sunshine</em> and, again, narrowly misses the chart double. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	As <em>Eternal Sunshine </em>(via Universal) enters a third week atop the <a  rel="nofollow"  href="https://www.aria.com.au/charts/albums-chart/2024-04-01"  target="_blank"  >ARIA Albums Chart</a>, Ariana’s album cut “We Can’t Be Friends (Wait For Your Love)” enters a second week at No. 2 on the national singles tally. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Coming in at No. 2 on the albums list is <a  href="https://www.billboard.com/artist/future/"  >Future</a> and <a  href="https://www.billboard.com/artist/metro-boomin/"  >Metro Boomin</a>’s <em>We Don’t Trust You</em> (Universal/Sony), their first collaborative collection. It’s Future’s 10th career title on the albums chart, including a No. 1 with 2022’s <em>I Never Liked You</em>. Metro Boomin landed at No. 4 in 2020 with <em>Savage Mode II</em>, a collaboration with 21 Savage, and solo LP <em>Heroes &amp; Villains</em> peaked at No. 5 in 2022. Three tracks from <em>We Don’t Trust You</em> appear on the ARIA Singles Chart, led by “Like That” at No. 8.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Closing out the top three on the ARIA Albums Chart, published Friday, March 29, is <a  href="https://www.billboard.com/artist/olivia-rodrigo/"  >Olivia Rodrigo</a>’s sophomore LP <em>Guts</em> (Geffen/Universal), which benefits from the release of the &#8220;Spilled&#8221; edition, which includes one new track and four songs that were previously only available on wax. One of those new releases “Obsessed,” arrives at No. 16 on the singles chart, for Rodrigo&#8217;s 16th top 20 appearance, ARIA reports. Three of those have climbed the chart mountain: “Drivers Licence,” “Good 4 U” and “Vampire.” Following its September 2023 release, <em>Guts</em> debuted at No. 1 in Australia and logged two weeks at the summit. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Meanwhile, Australian pop duo <a  href="https://www.billboard.com/artist/the-veronicas/"  >the Veronicas</a> bag a top 10 debut with<em> Gothic Summer</em> (Virgin Music Australia/Universal). Produced by Goldfinger&#8217;s John Feldmann and featuring a cast of <a  href="https://www.billboard.com/music/pop/the-veronicas-gothic-summer-stream-it-now-1235639333/"  >top-flight collaborators</a>, including Travis Barker, <em>Gothic Summer</em> is new at No. 6. The Brisbane sisters (Jessica and Lisa Origliasso) have cracked the top 10 with all six of their studio albums, the first three of which peaked No. 2: <em>The Secret Life Of…</em> (2005), <em>Hook Me Up</em> (2007) and <em>The Veronicas</em> (2014). </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Over on the <a  rel="nofollow"  href="https://www.aria.com.au/charts/singles-chart/2024-04-01"  target="_blank"  >ARIA Singles Chart</a>, also published Friday, <a  href="https://www.billboard.com/artist/benson-boone/"  >Benson Boone</a> bags a fourth week at No. 1 with “Beautiful Things,” atop an unchanged top three.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Finally, Irish singer and songwriter <a  href="https://www.billboard.com/artist/hozier/"  >Hozier</a> returns to the top 10 with “Too Sweet” (Columbia/Sony), new at No. 10. That’s his first solo top 40 hit since 2015, when &#8220;Someone New&#8221; peaked at No. 24. His career best in these parts came with his 2013’s “Take Me To Church,” which sailed to No. 2. <br></p>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>AEG Presents&#8217; Jay Marciano to Receive City of Hope 2024 Spirit of Life&#160;Award</title>
# 		<link>https://www.billboard.com/music/awards/aeg-presents-jay-marciano-city-of-hope-2024-spirit-of-life-award-1235644400/</link>
#
# 		<dc:creator><![CDATA[Lars Brandle]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 05:22:36 +0000</pubDate>
# 				<category><![CDATA[Awards]]></category>
# 		<category><![CDATA[Music]]></category>
# 		<category><![CDATA[bbnews]]></category>
# 		<category><![CDATA[City of Hope]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644400</guid>
#
# 					<description><![CDATA[“It’s deeply meaningful to be honored for this recognition,” says AEG Presents chairman and CEO Jay Marciano.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	AEG Presents chairman and CEO Jay Marciano will be honored with the City of Hope’s 2024 Spirit of Life Award, the cancer research and treatment organization has announced.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	“It’s deeply meaningful to be honored for this recognition,” says Marciano, a regular entry in <a  href="https://www.billboard.com/h/billboard-2024-power-100-list/"  ><em>Billboard’s</em> Power 100 list</a>. “Our industry’s work contributes to bringing the brightest minds in the world to make breakthrough medical discoveries — discoveries that give back the gift of time to people.&#8221;</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The award is the charitable organization’s most prestigious honor and is presented those industry leaders who have made notable contributions to their community and profession. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Previous recipients from the music industry include Lyor Cohen, Shelli and Irving Azoff, Edgar Bronfman Jr., Coran Capshaw, Eddy Cue, Clive Davis, Sir Lucian Grainge, Sylvia Rhone and more.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	&#8220;I am honored to join this admirable group of Spirit of Life recipients,&#8221; Marciano adds, &#8220;and look forward to continuing the tradition of leaning on music, film and the arts to raise awareness of and funding for City of Hope’s important work against cancer, diabetes and other life-threatening diseases.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	City of Hope’s Music, Film and Entertainment Industry fundraising group will present Marciano with the award during a gala dinner this fall in Los Angeles.  </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	A leader in the live entertainment business, Marciano began presenting shows in his 20s, before taking on senior leadership roles at Universal Concerts, AEG Europe and Madison Square Garden Entertainment, then returning to the AEG fold in 2011. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	With Marciano at the helm, AEG Presents has promoted tours from many of the music industry’s biggest artists, including stadium juggernauts Elton John, the Rolling Stones, Taylor Swift and Ed Sheeran, and overseen a festival portfolio upwards of 30 brands from Coachella Valley Music and Arts Festival to Stagecoach, Electric Forest, British Summertime Hyde Park and more. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Marciano has also overseen the company’s global growth with the opening of several international offices and an expansion into Australia, Singapore, Japan and France.  </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	In its 50-plus-year history, City of Hope’s MFEI group has raised over $150 million for good causes, specifically cancer research. Marciano has a reputation “as an industry leader who is eager to accelerate City of Hope’s mission and focus on making breakthrough discoveries that move us closer to putting an end to cancer,” said Kristin Bertell, chief philanthropy officer at City of Hope. “We look forward to partnering with him and the larger music community to develop new cures, save patient lives and ensure that everyone has an equal opportunity to secure their highest level of health.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The announcement launches City of Hope’s year-long fundraising initiatives that include the Taste of Hope in NYC in April, Future Hope Poker Tournament and Songs of Hope.  </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	To contribute or learn more visit <a  rel="nofollow"  href="http://jaymarcianospiritoflife.com/"  target="_blank"  >jaymarcianospiritoflife.com</a> and <a  rel="nofollow"  href="https://www.cityofhope.org/"  target="_blank"  >cityofhope.org</a>.</p>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Beyoncé&#8217;s &#8216;Jolene&#8217; Lyrics vs. Dolly Parton&#8217;s Original: What&#8217;s New &#038; What&#8217;s the&#160;Same?</title>
# 		<link>https://www.billboard.com/music/lyrics/beyonce-jolene-lyrics-vs-dolly-parton-original-1235644425/</link>
#
# 		<dc:creator><![CDATA[Katie Atkinson]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 04:42:58 +0000</pubDate>
# 				<category><![CDATA[Lyrics]]></category>
# 		<category><![CDATA[Music]]></category>
# 		<category><![CDATA[Country]]></category>
# 		<category><![CDATA[lyrics]]></category>
# 		<category><![CDATA[Music News]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644425</guid>
#
# 					<description><![CDATA[On the just-released <em>Cowboy Carter</em> album, Beyoncé included a melodically faithful but lyrically updated version of Parton's 1973 classic "Jolene."]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# ...
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Diplo was hyped to hear that MGK and Trippie were connecting as he chimed in with <a  href="https://www.instagram.com/p/C4v-YobvHAX/?hl=en"  target="_blank"  rel="noreferrer noopener nofollow"  >an Instagram comment</a> last week: “This is going to [be] f—–g good!”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	MGK and Trippie have proven to be a dynamic combination while collaborating on genre-blending records over the years like&nbsp;<em>Hotel Diablo</em>‘s “Candy,”&nbsp;<em>Tickets to My Downfall</em>‘s “All I Know” as well as “Red Sky” and “Pill Breaker.”</p>
#
#
#
# <figure class="wp-block-embed is-type-rich is-provider-instagram wp-block-embed-instagram"><div class="wp-block-embed__wrapper">
# <blockquote class="instagram-media" data-instgrm-captioned data-instgrm-permalink="https://www.instagram.com/p/C48eqdvukz6/?utm_source=ig_embed&amp;utm_campaign=loading" data-instgrm-version="14" style=" background:#FFF; border:0; border-radius:3px; box-shadow:0 0 1px 0 rgba(0,0,0,0.5),0 1px 10px 0 rgba(0,0,0,0.15); margin: 1px; max-width:500px; min-width:326px; padding:0; width:99.375%; width:-webkit-calc(100% - 2px); width:calc(100% - 2px);"><div style="padding:16px;"> <a  href="https://www.instagram.com/p/C48eqdvukz6/?utm_source=ig_embed&#038;utm_campaign=loading"  style=" background:#FFFFFF; line-height:0; padding:0 0; text-align:center; text-decoration:none; width:100%;"  target="_blank"  rel="nofollow"  > <div style="flex-direction: row;align-items: center"> <div style="background-color: #F4F4F4;border-radius: 50%;flex-grow: 0;height: 40px;margin-right: 14px;width: 40px"></div> <div style="flex-direction: column;flex-grow: 1;justify-content: center"> <div style="background-color: #F4F4F4;border-radius: 4px;flex-grow: 0;height: 14px;margin-bottom: 6px;width: 100px"></div> <div style="background-color: #F4F4F4;border-radius: 4px;flex-grow: 0;height: 14px;width: 60px"></div></div></div><div style="padding: 19% 0"></div> <div style="height:50px;margin:0 auto 12px;width:50px"><svg width="50px" height="50px" viewBox="0 0 60 60" xmlns="https://www.w3.org/2000/svg"><g fill="none"><g transform="translate(-511.000000, -20.000000)" fill="#000000"><g><path d="M556.869,30.41 C554.814,30.41 553.148,32.076 553.148,34.131 C553.148,36.186 554.814,37.852 556.869,37.852 C558.924,37.852 560.59,36.186 560.59,34.131 C560.59,32.076 558.924,30.41 556.869,30.41 M541,60.657 C535.114,60.657 530.342,55.887 530.342,50 C530.342,44.114 535.114,39.342 541,39.342 C546.887,39.342 551.658,44.114 551.658,50 C551.658,55.887 546.887,60.657 541,60.657 M541,33.886 C532.1,33.886 524.886,41.1 524.886,50 C524.886,58.899 532.1,66.113 541,66.113 C549.9,66.113 557.115,58.899 557.115,50 C557.115,41.1 549.9,33.886 541,33.886 M565.378,62.101 C565.244,65.022 564.756,66.606 564.346,67.663 C563.803,69.06 563.154,70.057 562.106,71.106 C561.058,72.155 560.06,72.803 558.662,73.347 C557.607,73.757 556.021,74.244 553.102,74.378 C549.944,74.521 548.997,74.552 541,74.552 C533.003,74.552 532.056,74.521 528.898,74.378 C525.979,74.244 524.393,73.757 523.338,73.347 C521.94,72.803 520.942,72.155 519.894,71.106 C518.846,70.057 518.197,69.06 517.654,67.663 C517.244,66.606 516.755,65.022 516.623,62.101 C516.479,58.943 516.448,57.996 516.448,50 C516.448,42.003 516.479,41.056 516.623,37.899 C516.755,34.978 517.244,33.391 517.654,32.338 C518.197,30.938 518.846,29.942 519.894,28.894 C520.942,27.846 521.94,27.196 523.338,26.654 C524.393,26.244 525.979,25.756 528.898,25.623 C532.057,25.479 533.004,25.448 541,25.448 C548.997,25.448 549.943,25.479 553.102,25.623 C556.021,25.756 557.607,26.244 558.662,26.654 C560.06,27.196 561.058,27.846 562.106,28.894 C563.154,29.942 563.803,30.938 564.346,32.338 C564.756,33.391 565.244,34.978 565.378,37.899 C565.522,41.056 565.552,42.003 565.552,50 C565.552,57.996 565.522,58.943 565.378,62.101 M570.82,37.631 C570.674,34.438 570.167,32.258 569.425,30.349 C568.659,28.377 567.633,26.702 565.965,25.035 C564.297,23.368 562.623,22.342 560.652,21.575 C558.743,20.834 556.562,20.326 553.369,20.18 C550.169,20.033 549.148,20 541,20 C532.853,20 531.831,20.033 528.631,20.18 C525.438,20.326 523.257,20.834 521.349,21.575 C519.376,22.342 517.703,23.368 516.035,25.035 C514.368,26.702 513.342,28.377 512.574,30.349 C511.834,32.258 511.326,34.438 511.181,37.631 C511.035,40.831 511,41.851 511,50 C511,58.147 511.035,59.17 511.181,62.369 C511.326,65.562 511.834,67.743 512.574,69.651 C513.342,71.625 514.368,73.296 516.035,74.965 C517.703,76.634 519.376,77.658 521.349,78.425 C523.257,79.167 525.438,79.673 528.631,79.82 C531.831,79.965 532.853,80.001 541,80.001 C549.148,80.001 550.169,79.965 553.369,79.82 C556.562,79.673 558.743,79.167 560.652,78.425 C562.623,77.658 564.297,76.634 565. ...
# </div></figure>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<em>Genre : Sadboy</em>&nbsp;is the first project offering of the year for both Machine Gun Kelly and Redd. The pair released&nbsp;<a  href="https://www.billboard.com/music/rb-hip-hop/machine-gun-kelly-dont-let-me-go-video-tattoo-1235611961/"  >solo singles</a>&nbsp;earlier in March before &#8220;lost boys&#8221; arrived this week. </p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The Cleveland native’s last released a rap album in 2019 with&nbsp;<em>Hotel Diablo</em>&nbsp;which followed MGK’s lucrative rock pivot. 2022’s&nbsp;<em>Mainstream Sellout</em>&nbsp;debuted at No. 1 atop the&nbsp;<a  href="https://www.billboard.com/charts/billboard-200/"  >Billboard 200</a>&nbsp;with 93,000 album units sold.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Trippie kept busy last year feeding fans with essentially three different projects between&nbsp;<em>Mansion Musik</em>,<em>&nbsp;A Love Letter to You 5</em>&nbsp;and the&nbsp;<em>Saint Michael V2</em>&nbsp;deluxe.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Stream <em>Genre : Sadboy</em> below.</p>
#
#
#
# <figure class="wp-block-embed is-type-rich is-provider-spotify wp-block-embed-spotify"><div class="wp-block-embed__wrapper">
# <iframe title="Spotify Embed: genre : sadboy" style="border-radius: 12px" width="100%" height="352" frameborder="0" allowfullscreen allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy" src="https://open.spotify.com/embed/album/1WkykSHhndyQJcYNwL7zxY?si=-oYCMQYNRB-I4iCI45WxfQ&#038;utm_source=oembed"></iframe>
# </div></figure>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>J-Hope’s ‘Hope on the Street Vol. 1’ Is Here: Stream It&#160;Now</title>
# 		<link>https://www.billboard.com/music/pop/j-hope-hope-on-the-street-vol-1-stream-1235644317/</link>
#
# 		<dc:creator><![CDATA[Rania Aniftos]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 04:02:15 +0000</pubDate>
# 				<category><![CDATA[Music]]></category>
# 		<category><![CDATA[Pop]]></category>
# 		<category><![CDATA[K-Pop]]></category>
# 		<category><![CDATA[Music News]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235644317</guid>
#
# 					<description><![CDATA[The mini-album is accompanied by a docuseries of the same name.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<a  href="https://www.billboard.com/artist/j-hope/"  >J-Hope</a> keeps on spreading the hope. The <a  href="https://www.billboard.com/artist/bts/"  >BTS</a> superstar unveiled his long awaited album, <em>Hope on the Street Vol. 1</em>, on Friday (March 29).</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The six-track mini-album was described in a press release as spanning a “diverse array of sounds and moods that showcase j-hope’s musical prowess and depth.” It also features a number of special guests, including band mate Jung Kook on “i wonder,” as well as Benny Blanco and Chic’s Nile Rodgers on “lock/ unlock,” a dance mix of “what if” with Jinbo the SuperFreak and “NEURON” featuring South Korean hip-hop vet Gaeko of Dynamic Duo and yoonmirae.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The album is accompanied by a deeper dive into J-Hope’s artistic roots and street dance background in an accompanying six-part docuseries, also named&nbsp;<em>Hope on the Street</em>, which debuted earlier this week on Prime Video.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	The project follows J-Hope’s 2022 solo album,<em>&nbsp;Jack in the Box</em>, which peaked at No. 6 on the&nbsp;<a  href="https://www.billboard.com/charts/billboard-200/"  >Billboard 200</a> albums chart. A newly expanded&nbsp;<em>HOPE Edition</em>&nbsp;of the album was released in August 2023. It features the original album tracks, along with three live recordings from&nbsp;<a  href="https://www.billboard.com/music/concerts/j-hope-lollapalooza-2022-set-moments-1235121113/"  >J-Hope’s history-making performance at Lollapalooza</a>&nbsp;in 2022 in Chicago, plus two instrumental tracks.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Listen to J-Hope’s <em>Hope on the Street Vol. 1</em> in full below. </p>
#
#
#
# <figure class="wp-block-embed is-type-rich is-provider-spotify wp-block-embed-spotify"><div class="wp-block-embed__wrapper">
# <iframe title="Spotify Embed: HOPE ON THE STREET VOL.1" style="border-radius: 12px" width="100%" height="352" frameborder="0" allowfullscreen allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy" src="https://open.spotify.com/embed/album/5mqxdPWQirLBE7vdDMhlB4?si=gXCrZ0gGThOkledy9a16pg&#038;utm_source=oembed"></iframe>
# </div></figure>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 		<item>
# 		<title>Enrique Iglesias Drops &#8216;Final, Vol. 2&#8217; Feat. Belinda, El Alfa &#038; More: Stream It&#160;Now</title>
# 		<link>https://www.billboard.com/music/latin/enrique-iglesias-new-album-final-vol-2-stream-it-now-1235643491/</link>
#
# 		<dc:creator><![CDATA[Jessica Roiz]]></dc:creator>
# 		<pubDate>Fri, 29 Mar 2024 04:00:18 +0000</pubDate>
# 				<category><![CDATA[Latin]]></category>
# 		<category><![CDATA[Music]]></category>
# 		<guid isPermaLink="false">https://www.billboard.com/?p=1235643491</guid>
#
# 					<description><![CDATA[ "Final, Vol. 2" follows Iglesias' <em>Vol. 1</em> (2021) and marks the last album of his career.]]></description>
# 										<content:encoded><![CDATA[<!-- do not apply CSS styles to this element! -->
# 				<div class="pmc-paywall">
#
#
#
#
#
#
#
#
#
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<a  href="https://www.billboard.com/music/enrique-iglesias"  >Enrique Iglesias</a> has released his new studio album <em>Final, Vol. 2</em> (Sony Music Latin)—almost three years after dropping <em>Final, Vol. 1</em>, and which he assures will be the last musical set of his career.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	Home to 10 tracks, the album finds Iglesias navigating from his signature electronic dance and Latin pop fusions to other genres including bachata (“Así Es La Vida” featuring Maria Becerra), dembow (“La Botella” featuring El Alfa), country (“Space in my Heart” featuring Miranda Lambert), and cumbia (“Llórame Un Río featuring Belinda). His collab with Lambert is also available in Spanish with only Iglesias performing it called &#8220;Espacio En Tu Corazón.”</p>
#
#
# <div class="injected-related-story // lrv-u-margin-tb-2 lrv-u-border-t-1 lrv-u-border-b-1 lrv-u-padding-t-050 lrv-u-padding-b-075 lrv-u-border-color-grey" >
# 			<div class="a-heading-border a-heading-border-background-color-grey a-heading-border-height-075 lrv-u-margin-b-075 lrv-u-margin-b-050@mobile-max">
#
# <h3 id="title-of-a-story" class="c-title  lrv-u-color-brand-primary a-font-primary-bold-s lrv-u-text-transform-uppercase lrv-u-padding-r-1 a-article-related-module-title a-article-related-module-title--color-brand-primary">
#
#
#
#
# 					Related
#
# </h3>
# 		</div>
#
#
# <div class="o-card lrv-u-flex">
#
# 			<a  tabindex="0"  href="https://www.billboard.com/music/country/miranda-lambert-enrique-iglesias-space-in-my-heart-stream-1235612821/"  class="lrv-u-flex lrv-a-unstyle-link lrv-u-color-brand-primary:hover"  >
#
#
# 		<div class="o-card__image-wrap lrv-u-flex-shrink-0 u-flex-basis-144 u-flex-basis-96@mobile-max">
#
#
# <div class="c-lazy-image  lrv-u-height-100p">
#
# 			<div class="a-crop-3x2 a-crop-1x1@mobile-max lrv-u-height-100p">
#
# 						<img decoding="async" class="c-lazy-image__img lrv-u-background-color-grey-lightest lrv-u-width-100p lrv-u-display-block lrv-u-height-auto" src="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/public/lazyload-fallback.gif" data-lazy-src="https://www.billboard.com/wp-content/uploads/2024/02/Enrique-Iglesia-and-Miranda-Lambert-billboard-1548.jpg?w=237&#038;h=147&#038;crop=1" alt="Miranda Lambert and Enrique Iglesia" data-lazy-srcset="" data-lazy-sizes="" height="" width="">
#
# 			</div>
#
# 	</div>
#
#
# 			</div>
#
# 	<div class="o-card__content lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-padding-lr-1 lrv-u-padding-lr-075@mobile-max">
#
#
#
# 		<div class="o_category ">
# 					</div>
#
# 		<div class="c_title ">
#
# <h3 id="title-of-a-story" class="c-title  a-font-primary-medium-m lrv-u-padding-b-050 u-letter-spacing-0028@mobile-max">
#
#
#
#
# 					Enrique Iglesias &amp; Miranda Lambert Team Up for &#8216;Space in My Heart&#8217;: Listen&nbsp;Now
#
# </h3>
# 									</div>
#
#
#
# <time class="c-timestamp  a-font-primary-medium-xxs lrv-u-color-brand-primary lrv-u-order-100" datetime="00:00-YY-DD-MM">
# 	03/29/2024
# </time>
#
#
#
#
#
#
# 			</div>
#
# 		</a>
#
# </div>
# 	</div>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	In addition to “Space in my Heart,” two other songs on the set are in English: “Love and Pain” and “Be Together”—further stamping the Spanish crooner’s global connection to his fans.</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	His sensual bachata with Becerra reached No. 1 on the<em> Billboard</em> Tropical Airplay chart for eight weeks, starting the Dec. 9, 2023-dated chart, and it reached a No. 12 high on Latin Airplay chart (Dec. 16).</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<em>Final, Vol. 2</em> follows <em>Final, Vol. 1</em> (2021), his first album in seven years after<em> Sex &amp; Love</em> and that includes hits such as the Nicky Jam-assisted “El Perdón,” “Duele el Corazón” with Wisin, “Súbeme la Radio” with Descemer Bueno and Zion y Lennox, and the Bad Bunny-assisted “El Baño.”</p>
#
#
#
# <p
# 		class="paragraph larva // lrv-u-margin-lr-auto  lrv-a-font-body-m   "
# >
# 	<em>Final (Vol. 1)</em> debuted and peaked at No. 12 on Top Latin Albums and at No. 2 on Latin Pop Albums (charts dated Oct. 10, 2021). Stream and listen to <em>Final, Vol. 2</em>, below:</p>
#
#
#
# <figure class="wp-block-embed is-type-rich is-provider-spotify wp-block-embed-spotify"><div class="wp-block-embed__wrapper">
# <iframe title="Spotify Embed: FINAL (Vol.2)" style="border-radius: 12px" width="100%" height="352" frameborder="0" allowfullscreen allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture" loading="lazy" src="https://open.spotify.com/embed/album/5LHd4piJoHcz4CXhjsFKxx?si=pxmq4xwLSzO7H0k5QTEskw&#038;utm_source=oembed"></iframe>
# </div></figure>
#
#
#
#
#
#
#
#
#
#
#
#
# </div>]]></content:encoded>
#
#
#
# 			</item>
# 	</channel>
# </rss>
